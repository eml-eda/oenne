# %% [markdown]
# # Neural Architecture Search with PLiNIO

# %% [markdown]
# This notebook contains the following sections:
#
# - Initial training of the "seed model"
# - Neural Architecture Search with the Plinio library, using the SuperNet algorithm (DARTS-like)
# - Structured Pruning with the Plinio library, using the PIT algorithm

# %% [markdown]
# ## Simple Training

# %% [markdown]
# ### Training scheme
# The first step is a simple training of an un-optimized model, which will be our "baseline" to evaluate the effectiveness of various optimizations. We are here:

# %% [markdown]
# ![train1.png](data:image/png;base64,...)
